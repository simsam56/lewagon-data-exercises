# %% [markdown]
# # Your First Neural Network

# %% [markdown]
# 🎯 Goals of this challenge:
# - Writing the architecture of a Neural Network
# - Inspect some of the most important hyperparameters of a Neural Network

# %% [markdown]
# 🌗 In this challenge, we will be working with the **moons dataset**.
# * Your goal is to build a Neural Network which separates two classes.
# * Each data point $X$ has two coordinates $X = (x_1, x_2)$ and belongs to either the class 0 or the class 1
# * These bi-dimensional points can be represented on a 2D-scatterplot, using colors to represent to two available classes $\color{blue}{blue}$ and $\color{red}{red} $
# * Here is an example of such a moon dataset:
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/moons_dataset.png" />

# %% [markdown]
# ## (1)  Generating the Moons dataset

# %% [markdown]
# 📚 Here, we will use the Scikit-Learn `make_moons` function [(see documentation here)](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html) to create 2 moons that cannot be linearly separated.
#
# 👉 Each moon corresponds to a class.

# %%
from sklearn.datasets import make_moons

### Generating the moons dataset
X, y = make_moons(n_samples=300, noise=0.3, random_state=0)

# %%
### This function allows to plot the two moons

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_moons(X, y):
    df = pd.DataFrame(dict(x1=X[:,0], x2=X[:,1], label=y))
    colors = {0:'red', 1:'blue'}
    fig, ax = plt.subplots()
    grouped = df.groupby('label')

    for key, group in grouped:
        group.plot(ax=ax, kind='scatter', x='x1', y='x2', label=key, color=colors[key])


    plt.title(f"{len(X)} moons")
    plt.show()

plot_moons(X, y)

# %% [markdown]
# ❓  Play with the number of samples and the noise to discover the effects on the `moons dataset` ❓
#
# 🎨 Plot the moons for different values.

# %%
# YOUR CODE HERE

# %% [markdown]
# ❓ Create 250 samples of the data with ❓
# * a noise equal to 0.20
# * a random state equal to 0 to get the same results every time you re-run the notebook
# * and split the initial dataset into a train and test set (size: 70/30%)
#
# *Remark* : Please call the variables `X_train`, `y_train`, `X_test` and `y_test`

# %%
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

# Génération du dataset
X, y = make_moons(n_samples=250, noise=0.20, random_state=0)

X_train, X_test, y_train,y_test  = train_test_split(
    X, y, test_size = 0.3, random_state = 0
)
print(X_train.shape, X_test.shape)
# Out:
# (175, 2) (75, 2)

# %%
plot_moons(X_train, y_train)

# %%
plot_moons(X_test, y_test)

# %% [markdown]
# ## (2) Designing a basic Neural Network  for a binary classification task

# %% [markdown]
# 🧠 You will now define your first neural network.
# The architecture of your model should have:
# - a first layer with:
#     - 5 neurons
#     - a _relu_ activation function
#     - the correct input dimension
# - an output layer suited to your binary classification task.
#
#
# ❓ Complete the next function with the previous architecture ❓

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input, Dense

# %%
def initialize_model():

    #############################
    #  1 - Model architecture   #
    #############################

    model = Sequential([
        Input(shape=(2,)),
        Dense(5, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    

    #############################
    #  2 - Optimization Method  #
    #############################
    model.compile(loss='binary_crossentropy', # We've already mentioned this loss function in Logistic Regression
                  optimizer='adam', # Optimizer in Deep Learning = solver in Machine Learning | Adam = our best friend
                  metrics=['accuracy']) # Let's focus on the accuracy, our dataset is balanced

    return model

model = initialize_model()

# %% [markdown]
# ---
#
# <details>
#     <summary><i>Intuitions about the optimization method</i></summary>
#
# We'll keep this message short as you have a full course 📆 **Deep Learning - Optimizers, Loss, Fitting** coming soon.
#
# So, briefly speaking:
#
# - the ***.compile()*** tells your algorithm how to optimize the weights of your network when fitting the network on real data
#     - the ***binary_crossentropy*** is the "log-loss" that you have already seen in Machine Learning in the context of a Logistic Regression for classification
#     - To date, the ***adam*** optimizer is the gold standard in Deep Learning - an optimizer in Deep Learning is like a solver in Machine Learning: it provides an iterative method to minimize the loss function of an algorithm with respect to its parameters
#
# </details>
#
# ---

# %% [markdown]
# ❓ How many parameters does the model have?  ❓
#
# <details>
#     <summary><i>Hint</i></summary>
#
# The `.summary()`method displays:
#    - the stack of layers of your Neural Network
#    - the output shape after each layer
#    - the number of parameters for each layer (and consequently the total number of parameters)
#
# </details>

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 5)              │            15 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21 (84.00 B)
#  Trainable params: 21 (84.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## (3) Training your Neural Network

# %% [markdown]
# ❓You are now ready to train your algorithm.
#
# Let's go! Initialize your model and fit it on the training set using `100 epochs`!
#
# Store the results of the training into a `history` variable. ❓

# %%
history = model.fit(
    X_train, y_train,
    epochs = 100,
    verbose = 1
)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3886 - loss: 0.7806
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4629 - loss: 0.7746
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4857 - loss: 0.7689
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7632
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7575
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7522
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7469
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7414
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7360
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7308
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7257
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7206
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7156
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7107
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7058
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.7009
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.6961
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.6913
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.6866
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.6818
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 0.6771
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4914 - loss: 0.6726
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4800 - loss: 0.6680
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4743 - loss: 0.6635
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5314 - loss: 0.6593
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5543 - loss: 0.6547
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5657 - loss: 0.6505
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5771 - loss: 0.6463
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5829 - loss: 0.6420
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5943 - loss: 0.6378
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6057 - loss: 0.6336
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6114 - loss: 0.6296
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6343 - loss: 0.6255
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6457 - loss: 0.6215
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6629 - loss: 0.6176
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6629 - loss: 0.6137
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6686 - loss: 0.6100
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6743 - loss: 0.6062
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6914 - loss: 0.6027
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7029 - loss: 0.5991
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7143 - loss: 0.5955
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7143 - loss: 0.5923
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7143 - loss: 0.5887
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7200 - loss: 0.5854
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7371 - loss: 0.5823
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7429 - loss: 0.5790
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7486 - loss: 0.5758
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - loss: 0.5727
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7600 - loss: 0.5697
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7714 - loss: 0.5665
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7886 - loss: 0.5636
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7943 - loss: 0.5607
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7943 - loss: 0.5578
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8057 - loss: 0.5549
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8171 - loss: 0.5521
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.5494
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.5467
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.5441
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.5415
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.5390
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.5365
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8229 - loss: 0.5339
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8229 - loss: 0.5316
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.5292
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8343 - loss: 0.5268
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8343 - loss: 0.5246
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8343 - loss: 0.5223
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8343 - loss: 0.5201
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8343 - loss: 0.5178
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5157
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5135
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5115
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5093
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5074
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5054
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5034
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5014
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4995
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4976
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4957
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4939
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4920
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4902
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4884
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4867
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4849
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4831
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4814
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4798
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4780
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4763
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4746
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4729
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4713
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4697
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4680
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4664
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4647
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4630
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4614

# %% [markdown]
# 👀 `history` contains information about the training.
#
# ❓ Inspect all its attributes using `history.__dict__`. You will notice that you have access to epoch-by-epoch information stored in `history.history`

# %%
# YOUR CODE HERE

# %% [markdown]
# ❓ Plot the history of the train loss using the following function ❓

# %%
def plot_history(history):
    plt.plot(history.history['loss'])
    plt.title('Train loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# ❓ What do you observe ❓

# %% [markdown]
# > YOUR ANSWER HERE

# %% [markdown]
# ❗️ <u>Evaluation on unseen data</u> ❗️
#
# 🧑🏻‍🏫 A Deep Learning Model is like any other Machine Learning model. Once you've trained it on the training set and are satisfied with how the Neural Network was able to learn, you need to ask: can it be generalized to unseen data such as the test set?

# %% [markdown]
# ## (4) Predict & Evaluate performance on test set

# %% [markdown]
# ❓ Predict the classes of the elements in the training set using _.predict()_ and store these predicted classes into a variable called `y_pred` ❓

# %%
Y_pred = model.predict(X_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# ❓ What are your _loss_ and your _accuracy_ on the test set ❓
#
# 💡 In other words, you are asked to evaluate your Deep Learning model!

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7600 - loss: 0.4686
# Test Loss: 0.4686
# Test Accuracy: 0.7600

# %%
accuracy=0.8267

# %% [markdown]
# **🧪 Test your code**

# %%
from nbresult import ChallengeResult
result = ChallengeResult('first_model', accuracy=accuracy)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/simonhingant/.pyenv/versions/3.12.9/envs/lewagon/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/simonhingant/code/simsam56/06-Deep-Learning/01-Fundamentals-of-Deep-Learning/data-your-first-neural-network/tests
# plugins: anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 1 item
#
# test_first_model.py::TestFirstModel::test_accuracy PASSED                [100%]
#
# ============================== 1 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/first_model.pickle
#
# git commit -m 'Completed first_model step'
#
# git push origin master

# %% [markdown]
# ❓ Check the accuracy of your predictions visually by using our `plot_decision_regions` available in `utils/plots.py` ❓

# %%
from utils.plots import plot_decision_regions
plot_decision_regions(X_test, y_test, model)
# Out:
# 1787/1787 ━━━━━━━━━━━━━━━━━━━━ 0s 220us/step

# %% [markdown]
# 😥 It looks like we are **underfitting** a bit, right?
#
# 😁 We can try :
# - to train the model a bit longer...
# - ...or maybe to create a Deeper Neural network in the next section!

# %% [markdown]
# ## (5) Training your Neural Network with more epochs

# %% [markdown]
# ❓ Re-train the model for 500 iterations ❓
# - Don't forget to call the `initialize_model` function, otherwise, your initial parameters will be those you have already learned on the previous _.fit()_ ...!)
# - Plot the history to see how the loss changed over the different epochs/iterations.

# %%
model = initialize_model()

history = model.fit(
    X_train, y_train,
    epochs = 500,
    verbose = 1,
)

# %% [markdown]
# ❓ Did the test accuracy improve? ❓

# %%
# YOUR CODE HERE

# %% [markdown]
# <details>
#     <summary><i>Not really... explanations here</i></summary>
#
# * The accuracy did not increase by training the model with more epochs...
# * So when should have we stopped the training of this Deep Learning Model?
#     * Answer in the next chapter <b><i>Deep Learning - Optimizers, Loss and Fitting</i></b>
#
# </details>

# %% [markdown]
# ## (6) A Deeper Deep Learning Model

# %% [markdown]
# ❓ Let's try a **deeper** architecture that includes the following layers:
#
# - a first layer with 20 neurons (activation: `"relu"`)
# - a second layer with 10 neurons (activation: `"relu"`)
# - a third layer with 5 neurons (activation: `"relu"`)
# - an output layer suitable for this problem ❓

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


        #############################
        #  1 - Model architecture   #
        #############################

def initialize_model_2():
    model = Sequential([
        Dense(20, activation = 'relu', input_shape = (2,)),
        Dense(10, activation = 'relu'),
        Dense(5, activation = 'relu'),
        Dense(1, activation = 'sigmoid')
    ])

    #############################
    #  2 - Optimization Method  #
    #############################
    model.compile(loss='binary_crossentropy', # We've already mentioned this loss function in Logistic Regression
                  optimizer='adam', # Optimizer in Deep Learning = solver in Machine Learning | Adam = our best friend
                  metrics=['accuracy']) # Let's focus on the accuracy, our dataset is balanced

    return model

model = initialize_model_2()

# %%
model.summary()

# %% [markdown]
# ❓ What is the number of parameters of your new model ❓

# %%
# YOUR CODE HERE

# %% [markdown]
# ❓ Run your model on the previous dataset for 500 epochs and plot the loss afterwards ❓

# %%
model = initialize_model_2()

history = model.fit(
    X_train, y_train,
    epochs = 500,
    verbose = 1
)

# %%
plt.plot(history.history['loss'])
plt.title('training avec depper model')
plt.xlabel('epoch')
plt.ylabel('loss')

# %% [markdown]
# ❓ What is your accuracy on the test test ? Store it as `accuracy_deep` variable (`float`) ❓

# %%
loss, accuracy_deep = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy_deep:.4f}")

# %%
result=ChallengeResult('deeper_model', accuracy=

# %% [markdown]
# 🧪 **Test your code**

# %%
from nbresult import ChallengeResult
result = ChallengeResult('deeper_model',
                         accuracy=accuracy_deep)
result.write()
print(result.check())

# %% [markdown]
# ❓ Do you think we are overfitting on the noise ❓ Once again, use the `plot_decision_regions` function to help your intuition.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
#
# 🏁 Congratulations!
#
# 💾 Don't forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move on to the next challenge!
