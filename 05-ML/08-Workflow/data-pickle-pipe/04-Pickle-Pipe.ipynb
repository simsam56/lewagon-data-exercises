# %% [markdown]
# # Pickle Pipe

# %% [markdown]
# 👇 Load the pipeline you exported in the previous exercise and predict if the following player will last more than 5 years as a professional or not.

# %%
import numpy as np
import pandas as pd

new_data = pd.read_csv("https://wagon-public-datasets.s3.amazonaws.com/05-Machine-Learning/08-Workflow/pickle_pipe_data.csv")
new_data
# Out:
#    games played  minutes played  points per game  field goals made  \
# 0          35.0             6.9              2.3               0.9
#
#    field goal attempts  field goal percent  3 point made  3 point attempt  \
# 0                  2.4                36.5           0.0              0.1
#
#    3 point %  free throw made  free throw attempts  free throw %  \
# 0       33.3              0.5                  0.6          81.8
#
#    offensive rebounds  defensive rebounds  rebounds  assists  steals  blocks  \
# 0                 0.5                 0.3       0.9      0.7     0.1     0.1
#
#    turnovers
# 0        0.3

# %%
predicted_class = None # 0 or 1

# %%
import pickle

with open("../data-tuning-pipeline/pipeline.pkl", "rb") as f:
    my_pipeline = pickle.load(f)

# %%
predicted_class = [ my_pipeline.predict(new_data)[0] ]
predicted_class
# Out:
# [0]

# %%
from nbresult import ChallengeResult

result = ChallengeResult(
    'solution',
    predicted_class=predicted_class
)

result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/simonhingant/.pyenv/versions/3.12.9/envs/lewagon/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/simonhingant/code/simsam56/05-ML/08-Workflow/data-pickle-pipe/tests
# plugins: anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 1 item
#
# test_solution.py::TestSolution::test_solution PASSED                     [100%]
#
# ============================== 1 passed in 0.08s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/solution.pickle
#
# git commit -m 'Completed solution step'
#
# git push origin master

# %% [markdown]
# 🏁 Congratulation. Don't forget to add, commit and push your notebook.
